# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_24May.csv', header = 1, parse_dates = ['Date/Time'])
df.head()
# Out:
#             Date/Time    avg    max    min  avg.1  min.1  avg.2  avg.3  min.2  \
# 0 2023-05-24 10:00:00  30.99  32.39  29.91   18.1   17.4    633   2.41   2.07
# 1 2023-05-24 09:00:00  28.27  29.41  27.30   19.1   18.1    509   1.61   1.30
# 2 2023-05-24 08:00:00  26.52  27.70  25.49   19.7   19.3    320   1.15   0.92
# 3 2023-05-24 07:00:00  23.90  25.33  22.50   20.2   20.1     92   0.59   0.35
# 4 2023-05-24 06:00:00  22.53  22.77  22.27   20.1   19.9      7   0.36   0.30
#
#    avg.4  ...  avg.23  max.9  min.9  last.1  last.2  avg.24  max.10  min.10  \
# 0  46.34  ...    29.6   29.7   29.5    9672    6830       9      10       8
# 1  57.99  ...    29.5   29.6   29.5    9566    6798       6       7       5
# 2  66.72  ...    29.5   29.6   29.5    7021    6767       5       5       4
# 3  80.21  ...    29.5   29.5   29.5    6820    6599       3       3       2
# 4  86.50  ...    29.5   29.5   29.5    3786    6508       2       2       1
#
#    time.1  Daily ET0 [mm]
# 0      60             NaN
# 1      60             NaN
# 2      60             NaN
# 3      15             NaN
# 4       0             NaN
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Changing Column Names:

# %%
df.columns = ['Date/Time', 'air_temp_avg', 'air_temp_max', 'air_temp_min', 'dew_avg',
       'dew_min', 'solar_rad_avg', 'vpd_avg', 'vpd_min', 'rel_humi_avg',
       'rel_humi_max', 'rel_humi_min', 'precp_sum', 'leaf_wetness_time(min)',
       'wind_speed_avg', 'wind_speed_max', 'wind_gust_max', 'wind_dir_last',
       'eag_sm1_avg', 'eag_sm2_avg', 'eag_sm3_avg', 'eag_sm4_avg',
       'eag_sm5_avg', 'eag_sm6_avg', 'VIC1_avg', 'VIC2_avg', 'VIC3_avg',
       'VIC4_avg', 'VIC5_avg', 'VIC6_avg', 'soil_temp1_avg', 'soil_temp1_max',
       'soil_temp1_min', 'soil_temp2_avg', 'soil_temp2_max', 'soil_temp2_min',
       'soil_temp3_avg', 'soil_temp3_max', 'soil_temp3_min', 'soil_temp4_avg',
       'soil_temp4_max', 'soil_temp4_min', 'soil_temp5_avg', 'soil_temp5_max',
       'soil_temp5_min', 'soil_temp6_avg', 'soil_temp6_max', 'soil_temp6_min',
       'sp_last', 'bat_last', 'del_avg', 'del_max', 'del_min', 'sun_time',
       'Daily ET0 [mm]']

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'], format = "%d-%m-%Y %H:%M:%S")

# %%
df.set_index('Date/Time',inplace = True)

# %% [markdown]
# ## Reversing Dataframe to get Data in order according to date and time:

# %%
df = df[::-1]
df.head()
# Out:
#                      air_temp_avg  air_temp_max  air_temp_min  dew_avg  \
# Date/Time
# 2023-04-25 13:00:00         35.27         35.87         34.58      5.2
# 2023-04-25 14:00:00         35.97         36.71         35.51      6.0
# 2023-04-25 15:00:00         36.33         36.72         35.49      6.0
# 2023-04-25 16:00:00         36.58         36.99         36.16      5.9
# 2023-04-25 17:00:00         36.27         37.29         35.44      6.1
#
#                      dew_min  solar_rad_avg  vpd_avg  vpd_min  rel_humi_avg  \
# Date/Time
# 2023-04-25 13:00:00      3.8            625     4.81     4.68         15.60
# 2023-04-25 14:00:00      4.7            957     4.98     4.83         15.85
# 2023-04-25 15:00:00      4.7            811     5.10     4.91         15.60
# 2023-04-25 16:00:00      5.2            593     5.19     5.01         15.22
# 2023-04-25 17:00:00      5.2            409     5.07     4.78         15.71
#
#                      rel_humi_max  ...  soil_temp6_avg  soil_temp6_max  \
# Date/Time                          ...
# 2023-04-25 13:00:00         16.96  ...            31.0            33.7
# 2023-04-25 14:00:00         17.36  ...            27.8            28.5
# 2023-04-25 15:00:00         18.13  ...            27.3            27.4
# 2023-04-25 16:00:00         16.93  ...            27.2            27.4
# 2023-04-25 17:00:00         16.89  ...            27.2            27.2
#
#                      soil_temp6_min  sp_last  bat_last  del_avg  del_max  \
# Date/Time
# 2023-04-25 13:00:00            28.8     9365      6787       17       18
# 2023-04-25 14:00:00            27.5     9370      6796       18       18
# 2023-04-25 15:00:00            27.3     9351      6790       18       18
# 2023-04-25 16:00:00            27.2     8052      6778       18       19
# 2023-04-25 17:00:00            27.2     6949      6736       18       18
#
#                      del_min  sun_time  Daily ET0 [mm]
# Date/Time
# 2023-04-25 13:00:00       17        30             NaN
# 2023-04-25 14:00:00       17        60             NaN
# 2023-04-25 15:00:00       17        60             NaN
# 2023-04-25 16:00:00       17        60             NaN
# 2023-04-25 17:00:00       17        60             NaN
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Preprocessing:

# %%
df.isnull().sum()
# Out:
# air_temp_avg                0
# air_temp_max                0
# air_temp_min                0
# dew_avg                     0
# dew_min                     0
# solar_rad_avg               0
# vpd_avg                     0
# vpd_min                     0
# rel_humi_avg                0
# rel_humi_max                0
# rel_humi_min                0
# precp_sum                   0
# leaf_wetness_time(min)      0
# wind_speed_avg              0
# wind_speed_max              0
# wind_gust_max               0
# wind_dir_last               0
# eag_sm1_avg                 0
# eag_sm2_avg                 0
# eag_sm3_avg                 0
# eag_sm4_avg                 0
# eag_sm5_avg                 0
# eag_sm6_avg                 0
# VIC1_avg                    0
# VIC2_avg                    0
# VIC3_avg                    0
# VIC4_avg                    0
# VIC5_avg                    0
# VIC6_avg                    0
# soil_temp1_avg              0
# soil_temp1_max              0
# soil_temp1_min              0
# soil_temp2_avg              0
# soil_temp2_max              0
# soil_temp2_min              0
# soil_temp3_avg              0
# soil_temp3_max              0
# soil_temp3_min              0
# soil_temp4_avg              0
# soil_temp4_max              0
# soil_temp4_min              0
# soil_temp5_avg              0
# soil_temp5_max              0
# soil_temp5_min              0
# soil_temp6_avg              0
# soil_temp6_max              0
# soil_temp6_min              0
# sp_last                     0
# bat_last                    0
# del_avg                     0
# del_max                     0
# del_min                     0
# sun_time                    0
# Daily ET0 [mm]            665
# dtype: int64

# %%
df['Daily ET0 [mm]'].fillna(0, inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.columns
# Out:
# Index(['air_temp_avg', 'air_temp_max', 'air_temp_min', 'dew_avg', 'dew_min',
#        'solar_rad_avg', 'vpd_avg', 'vpd_min', 'rel_humi_avg', 'rel_humi_max',
#        'rel_humi_min', 'precp_sum', 'leaf_wetness_time(min)', 'wind_speed_avg',
#        'wind_speed_max', 'wind_gust_max', 'wind_dir_last', 'eag_sm1_avg',
#        'eag_sm2_avg', 'eag_sm3_avg', 'eag_sm4_avg', 'eag_sm5_avg',
#        'eag_sm6_avg', 'VIC1_avg', 'VIC2_avg', 'VIC3_avg', 'VIC4_avg',
#        'VIC5_avg', 'VIC6_avg', 'soil_temp1_avg', 'soil_temp1_max',
#        'soil_temp1_min', 'soil_temp2_avg', 'soil_temp2_max', 'soil_temp2_min',
#        'soil_temp3_avg', 'soil_temp3_max', 'soil_temp3_min', 'soil_temp4_avg',
#        'soil_temp4_max', 'soil_temp4_min', 'soil_temp5_avg', 'soil_temp5_max',
#        'soil_temp5_min', 'soil_temp6_avg', 'soil_temp6_max', 'soil_temp6_min',
#        'sp_last', 'bat_last', 'del_avg', 'del_max', 'del_min', 'sun_time',
#        'Daily ET0 [mm]'],
#       dtype='object')

# %% [markdown]
# ## Dropping Insignificant Features:

# %%
drop_feat = ['leaf_wetness_time(min)','eag_sm1_avg',
       'eag_sm2_avg', 'eag_sm3_avg', 'eag_sm4_avg', 'eag_sm5_avg',
       'eag_sm6_avg','VIC1_avg', 'VIC2_avg', 'VIC3_avg',
       'VIC4_avg', 'VIC5_avg', 'VIC6_avg', 'soil_temp1_avg', 'soil_temp1_max',
       'soil_temp1_min', 'soil_temp2_avg', 'soil_temp2_max', 'soil_temp2_min',
       'soil_temp3_avg', 'soil_temp3_max', 'soil_temp3_min', 'soil_temp4_avg',
       'soil_temp4_max', 'soil_temp4_min', 'soil_temp5_avg', 'soil_temp5_max',
       'soil_temp5_min', 'soil_temp6_avg', 'soil_temp6_max', 'soil_temp6_min',
       'sp_last', 'bat_last','sun_time', 'Daily ET0 [mm]']
df.drop(drop_feat, axis = 1, inplace = True)

# %%
df.head()
# Out:
#                      air_temp_avg  air_temp_max  air_temp_min  dew_avg  \
# Date/Time
# 2023-04-25 13:00:00         35.27         35.87         34.58      5.2
# 2023-04-25 14:00:00         35.97         36.71         35.51      6.0
# 2023-04-25 15:00:00         36.33         36.72         35.49      6.0
# 2023-04-25 16:00:00         36.58         36.99         36.16      5.9
# 2023-04-25 17:00:00         36.27         37.29         35.44      6.1
#
#                      dew_min  solar_rad_avg  vpd_avg  vpd_min  rel_humi_avg  \
# Date/Time
# 2023-04-25 13:00:00      3.8            625     4.81     4.68         15.60
# 2023-04-25 14:00:00      4.7            957     4.98     4.83         15.85
# 2023-04-25 15:00:00      4.7            811     5.10     4.91         15.60
# 2023-04-25 16:00:00      5.2            593     5.19     5.01         15.22
# 2023-04-25 17:00:00      5.2            409     5.07     4.78         15.71
#
#                      rel_humi_max  rel_humi_min  precp_sum  wind_speed_avg  \
# Date/Time
# 2023-04-25 13:00:00         16.96         14.68        0.0             1.4
# 2023-04-25 14:00:00         17.36         14.49        0.0             1.3
# 2023-04-25 15:00:00         18.13         14.05        0.0             1.2
# 2023-04-25 16:00:00         16.93         14.32        0.0             1.0
# 2023-04-25 17:00:00         16.89         14.66        0.0             0.8
#
#                      wind_speed_max  wind_gust_max  wind_dir_last  del_avg  \
# Date/Time
# 2023-04-25 13:00:00             1.8            3.9             38       17
# 2023-04-25 14:00:00             1.9            3.5             63       18
# 2023-04-25 15:00:00             1.9            3.6            160       18
# 2023-04-25 16:00:00             1.9            2.8             24       18
# 2023-04-25 17:00:00             1.2            2.8             94       18
#
#                      del_max  del_min
# Date/Time
# 2023-04-25 13:00:00       18       17
# 2023-04-25 14:00:00       18       17
# 2023-04-25 15:00:00       18       17
# 2023-04-25 16:00:00       19       17
# 2023-04-25 17:00:00       18       17

# %%
df.shape
# Out:
# (694, 19)

# %% [markdown]
# ## Basic Trend Plot of Average Wind Speed:

# %%
plt.figure(figsize = (10,4))
plt.plot(df['wind_speed_avg'])
plt.xlabel('Date and Time')
plt.ylabel('Average Wind Speed')
plt.grid()
plt.show()

# %% [markdown]
# ## Scaling:

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
df1 = pd.DataFrame(ms.fit_transform(df), columns = df.columns, index = df.index)
df1.head()
# Out:
#                      air_temp_avg  air_temp_max  air_temp_min   dew_avg  \
# Date/Time
# 2023-04-25 13:00:00      0.831024      0.823891      0.826897  0.000000
# 2023-04-25 14:00:00      0.862316      0.860782      0.869150  0.045455
# 2023-04-25 15:00:00      0.878409      0.861221      0.868242  0.045455
# 2023-04-25 16:00:00      0.889584      0.873079      0.898682  0.039773
# 2023-04-25 17:00:00      0.875726      0.886254      0.865970  0.051136
#
#                       dew_min  solar_rad_avg   vpd_avg   vpd_min  \
# Date/Time
# 2023-04-25 13:00:00  0.000000       0.552120  0.833622  0.843243
# 2023-04-25 14:00:00  0.048128       0.845406  0.863085  0.870270
# 2023-04-25 15:00:00  0.048128       0.716431  0.883882  0.884685
# 2023-04-25 16:00:00  0.074866       0.523852  0.899480  0.902703
# 2023-04-25 17:00:00  0.074866       0.361307  0.878683  0.861261
#
#                      rel_humi_avg  rel_humi_max  rel_humi_min  precp_sum  \
# Date/Time
# 2023-04-25 13:00:00      0.004502      0.000843      0.007420        0.0
# 2023-04-25 14:00:00      0.007464      0.005657      0.005183        0.0
# 2023-04-25 15:00:00      0.004502      0.014925      0.000000        0.0
# 2023-04-25 16:00:00      0.000000      0.000481      0.003180        0.0
# 2023-04-25 17:00:00      0.005806      0.000000      0.007185        0.0
#
#                      wind_speed_avg  wind_speed_max  wind_gust_max  \
# Date/Time
# 2023-04-25 13:00:00        0.518519        0.545455       0.542373
# 2023-04-25 14:00:00        0.481481        0.575758       0.474576
# 2023-04-25 15:00:00        0.444444        0.575758       0.491525
# 2023-04-25 16:00:00        0.370370        0.575758       0.355932
# 2023-04-25 17:00:00        0.296296        0.363636       0.355932
#
#                      wind_dir_last   del_avg   del_max   del_min
# Date/Time
# 2023-04-25 13:00:00       0.105850  0.944444  0.947368  0.944444
# 2023-04-25 14:00:00       0.175487  1.000000  0.947368  0.944444
# 2023-04-25 15:00:00       0.445682  1.000000  0.947368  0.944444
# 2023-04-25 16:00:00       0.066852  1.000000  1.000000  0.944444
# 2023-04-25 17:00:00       0.261838  1.000000  0.947368  0.944444

# %% [markdown]
# ## Function to create X and y

# %%
# generating a function that results in X and y such that
# [[row1] [row2] [row3] [row4]] ---> [windspeed5]
# [[row2] [row3] [row4] [row5]] ---> [windspeed6]
# [[row3] [row4] [row5] [row6]] ---> [windspeed7] and so on
def get_X_y(df, window_size = 4):
  target_idx = df.columns.get_loc('wind_speed_avg')
  # print(target_idx)
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [val for val in df_as_np[i:i+window_size]]
    X.append(row)
    labels = df_as_np[i+window_size][target_idx]
    y.append(labels)
  return np.array(X), np.array(y)

# %%
X, y = get_X_y(df1, 4)
X.shape, y.shape
# Out:
# ((690, 4, 19), (690,))

# %% [markdown]
# ## Train and Test Splits:

# %%
e5_percent = int(round((0.85*len(X)),0))
X_train, y_train = X[:e5_percent], y[:e5_percent]
X_test, y_test = X[e5_percent:], y[e5_percent:]

# %%
print("Training Shape:")
print(X_train.shape, y_train.shape)
print("Testing Shape:")
print(X_test.shape, y_test.shape)
# Out:
# Training Shape:
# (586, 4, 19) (586,)
# Testing Shape:
# (104, 4, 19) (104,)

# %% [markdown]
# # LSTM Model Fitting by performing Hyperparameter tuning:

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (1.3.5)
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from keras-tuner) (2.26.0)
# Requirement already satisfied: kt-legacy in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: packaging in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from keras-tuner) (23.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\laksh\appdata\local\programs\python\python39\lib\site-packages (from requests->keras-tuner) (1.26.7)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, Dense, GRU
from kerastuner.tuners import RandomSearch
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Creating Generalized LSTM building Function:

# %%
def build_model(hp):
    mod = Sequential()
    mod.add(InputLayer((4,19)))
    mod.add(LSTM(units = hp.Int('unit_', min_value = 20, max_value = 256, step = 18), return_sequences=True))
    mod.add(LSTM(units = hp.Int('unit1_', min_value = 1, max_value = 64, step = 4)))
    mod.add(Dense(units = hp.Int('unit_dense', min_value = 4, max_value = 128, step = 8), activation = 'linear'))
    mod.add(Dense(units = 1, activation = 'linear'))

    mod.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse'])
    return mod

# %% [markdown]
# ## Performing Fine Tuning:

# %%
tuner = RandomSearch(build_model, objective = 'mse', max_trials = 10, 
                     directory = 'tuner_directory', project_name = 'lstm_tuning')

# %%
tuner.search(X_train, y_train, validation_data = (X_test, y_test), epochs = 300)
# Out:
# Trial 10 Complete [00h 01m 12s]
# mse: 0.0026233040262013674
#
# Best mse So Far: 0.0010886569507420063
# Total elapsed time: 00h 10m 22s
# INFO:tensorflow:Oracle triggered exit

# %%
best_lstm_model = tuner.get_best_models(num_models = 1)[0]
best_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 4, 236)            241664
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1)                 952
# _________________________________________________________________
# dense (Dense)                (None, 84)                168
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 242,869
# Trainable params: 242,869
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Prediction Function:

# %%
def plot_line(m, X, y):
  pred = m.predict(X).flatten()
  df_pred = pd.DataFrame(data = {'Predictions':pred, 'Actual':y})
  # df_pred.plot(kind = 'line', figsize = (10,4))
  mse = mean_squared_error(y, pred)
  print("Mean Squared Error of Provided model is: ", mse)
  return df_pred, mse

# %% [markdown]
# ## Reverse Scaling Function:

# %%
min_ws = df['wind_speed_avg'].min()
max_ws = df['wind_speed_avg'].max()
print(f"Minimum Average Wind Speed: {min_ws} and Maximum Average wind Speed: {max_ws}")
# Out:
# Minimum Average Wind Speed: 0.0 and Maximum Average wind Speed: 2.7

# %%
def rev_min_max_func(scaled_val):
  og = (scaled_val*(max_ws - min_ws)) + min_ws
  return og

# %% [markdown]
# ## Training and Testing /Prediction using best LSTM:

# %%
training_pred, training_lstm_mse = plot_line(best_lstm_model, X_train, y_train)
# Out:
# Mean Squared Error of Provided model is:  0.0010857574903988733

# %%
test_pred, test_lstm_mse = plot_line(best_lstm_model, X_test, y_test)
# Out:
# Mean Squared Error of Provided model is:  0.012101963086144906

# %% [markdown]
# ## Train Data:

# %%
train_df = training_pred.applymap(rev_min_max_func)
# train_df['Date/Time'] = df.index[4:e5_percent + 4]
train_df.set_index(df1.index[4:e5_percent+4], inplace = True)
train_df.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-04-25 17:00:00     0.852056     0.8
# 2023-04-25 18:00:00     1.558883     1.6
# 2023-04-25 19:00:00     1.685141     1.7
# 2023-04-25 20:00:00     2.124869     2.1
# 2023-04-25 21:00:00     2.529291     2.4

# %%
#plotting:
# train_df[['Predictions','Actual']].plot(kind = 'line', figsize = (10, 4))
train_df.plot(kind = 'line', figsize = (10, 4))
plt.xlabel('Date and Time')
plt.ylabel('Average Wind Speed')
plt.show()

# %% [markdown]
# ## Test Data:

# %%
test_df = test_pred.applymap(rev_min_max_func)
# test_df['Date/Time'] = df.index[e5_percent+4:]
test_df.set_index(df1.index[e5_percent+4:], inplace = True)
test_df.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-05-20 03:00:00     0.608303     0.6
# 2023-05-20 04:00:00     0.509211     0.3
# 2023-05-20 05:00:00     0.863941     0.2
# 2023-05-20 06:00:00     0.389840     0.0
# 2023-05-20 07:00:00     0.110921     0.4

# %%
# test_df[['Predictions','Actual']].plot(kind = 'line', figsize = (10,4))
test_df.plot(kind = 'line', figsize = (10,4))
plt.xlabel('Date and Time')
plt.ylabel('Average Wind Speed')
plt.show()

# %% [markdown]
# ## Entire Data Prediction:

# %%
df_pred, df_lstm_mse = plot_line(best_lstm_model, X, y)
# df_pred['Date/Time'] = df.index[4:]
df_pred.set_index(df.index[4:], inplace = True)
# Out:
# Mean Squared Error of Provided model is:  0.002746171085214866

# %%
df_pred[['Predictions','Actual']] = df_pred[['Predictions','Actual']].applymap(rev_min_max_func)
df_pred.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-04-25 17:00:00     0.852056     0.8
# 2023-04-25 18:00:00     1.558883     1.6
# 2023-04-25 19:00:00     1.685141     1.7
# 2023-04-25 20:00:00     2.124869     2.1
# 2023-04-25 21:00:00     2.529291     2.4

# %%
#plotting:
# df_pred[['Predictions','Actual']].plot(kind = 'line', figsize = (10,4))
df_pred.plot(kind = 'line', figsize = (10,4))
plt.xlabel('Date and Time')
plt.ylabel('Average Wind Speed')
plt.title("Best LSTM")
plt.savefig('full_lstm_pred.png')

# %% [markdown]
# ## Actual MSE for Entire Data:

# %%
lstm_mse1 = mean_squared_error(df_pred['Actual'], df_pred['Predictions'])
print(f"Lowest Possible MSE after fine tuning is {lstm_mse1}")
# Out:
# Lowest Possible MSE after fine tuning is 0.020019587211216373

# %% [markdown]
# # GRU Fitting with Hyperparameter Tuning:

# %%
# generalized Function for GRU
def build_model1(hp):
    mod = Sequential()
    mod.add(InputLayer((4,19)))
    mod.add(GRU(units = hp.Int('unit_', min_value = 20, max_value = 256, step = 18), return_sequences=True)),
    mod.add(GRU(units = hp.Int('unit1_', min_value = 1, max_value = 64, step = 4))),
    mod.add(Dense(units = hp.Int('unit_dense', min_value = 4, max_value = 128, step = 8), activation = 'linear'))
    mod.add(Dense(units = 1, activation = 'linear'))

    mod.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse'])
    return mod

# %%
tuner1 = RandomSearch(build_model1, objective = 'mse', max_trials = 10, directory = 'tuner_directory', project_name = 'gru_training')

# %%
tuner1.search(X_train, y_train, validation_data = (X_test, y_test), epochs = 300)
# Out:
# Trial 10 Complete [00h 00m 52s]
# mse: 0.0023663549218326807
#
# Best mse So Far: 0.0010989385191351175
# Total elapsed time: 00h 09m 14s
# INFO:tensorflow:Oracle triggered exit

# %%
best_gru_model = tuner1.get_best_models(num_models=1)[0]
best_gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 4, 164)            91020
# _________________________________________________________________
# gru_1 (GRU)                  (None, 5)                 2565
# _________________________________________________________________
# dense (Dense)                (None, 100)               600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 94,286
# Trainable params: 94,286
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Prediction on Training and Test Data:

# %% [markdown]
# ## Train Data:

# %%
gru_train_pred, gru_train_mse = plot_line(best_gru_model, X_train, y_train)
# gru_train_pred['Date/Time'] = df.index[4:e5_percent+4]
gru_train_pred.set_index(df.index[4:e5_percent+4], inplace = True)
# Out:
# Mean Squared Error of Provided model is:  0.0009556440925833338

# %%
gru_train_pred[['Predictions','Actual']] = gru_train_pred[['Predictions','Actual']].applymap(rev_min_max_func)
gru_train_pred.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-04-25 17:00:00     0.871780     0.8
# 2023-04-25 18:00:00     1.686148     1.6
# 2023-04-25 19:00:00     1.722070     1.7
# 2023-04-25 20:00:00     2.014906     2.1
# 2023-04-25 21:00:00     2.367472     2.4

# %%
#plotting:
# gru_train_pred[['Predictions','Actual']].plot(kind = 'line', figsize = (10, 4))
gru_train_pred.plot(kind = 'line', figsize = (10, 4))
plt.xlabel('Index of Record')
plt.ylabel('Average Wind Speed')
plt.show()

# %% [markdown]
# ## Test Data:

# %%
gru_test_pred, gru_test_mse = plot_line(best_gru_model, X_test, y_test)
# gru_test_pred['Date/Time'] = df.index[e5_percent + 4:]
gru_test_pred.set_index(df.index[e5_percent+4:], inplace = True)
# Out:
# Mean Squared Error of Provided model is:  0.012655987416491156

# %%
gru_test_pred[['Predictions', 'Actual']] = gru_test_pred[['Predictions', 'Actual']].applymap(rev_min_max_func)
gru_test_pred.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-05-20 03:00:00     0.712368     0.6
# 2023-05-20 04:00:00     0.569024     0.3
# 2023-05-20 05:00:00     0.943375     0.2
# 2023-05-20 06:00:00     0.196898     0.0
# 2023-05-20 07:00:00     0.133283     0.4

# %%
# gru_test_pred[['Predictions', 'Actual']].plot(kind = 'line', figsize = (10, 4))
gru_test_pred.plot(kind = 'line', figsize = (10, 4))
plt.xlabel('Record Index')
plt.ylabel('Average Wind Speed')
plt.show()

# %% [markdown]
# ## Entire Data:

# %%
entire_gru_pred, entire_gru_mse = plot_line(best_gru_model, X, y)
# entire_gru_pred['Date/Time'] = df.index[4:]
entire_gru_pred.set_index(df.index[4:], inplace = True)
# Out:
# Mean Squared Error of Provided model is:  0.0027191741712687535

# %%
entire_gru_pred[['Predictions','Actual']] = entire_gru_pred[['Predictions','Actual']].applymap(rev_min_max_func)
entire_gru_pred.head()
# Out:
#                      Predictions  Actual
# Date/Time
# 2023-04-25 17:00:00     0.871780     0.8
# 2023-04-25 18:00:00     1.686148     1.6
# 2023-04-25 19:00:00     1.722070     1.7
# 2023-04-25 20:00:00     2.014906     2.1
# 2023-04-25 21:00:00     2.367472     2.4

# %%
#plotting:
# entire_gru_pred[['Predictions','Actual']].plot(kind = 'line', figsize = (10, 4))
entire_gru_pred.plot(kind = 'line', figsize = (10, 4))
plt.title('Best GRU')
plt.xlabel('Record Index')
plt.ylabel('Average Wind Speed')
plt.savefig('full_gru_pred.png')

# %% [markdown]
# ## Actual MSE of Best GRU model:

# %%
mse_gru = mean_squared_error(entire_gru_pred['Actual'], entire_gru_pred['Predictions'])
print(f"The lowest possible MSE using GRU is {mse_gru}")
# Out:
# The lowest possible MSE using GRU is 0.01982277970854922

# %% [markdown]
# ## Comparing Both Models:

# %%
from IPython.display import Image
from IPython.display import display
x1 = Image(filename='full_lstm_pred.png') 
y1 = Image(filename='full_gru_pred.png') 
display(x1, y1)

# %%
print(f"MSE for LSTM: {lstm_mse1}")
print(f"MSE for GRU : {mse_gru}")
# Out:
# MSE for LSTM: 0.020019587211216373
# MSE for GRU : 0.01982277970854922

# %% [markdown]
# ## Mean Absolute Error:

# %%
mae_lstm = mean_absolute_error(df_pred['Predictions'], df_pred['Actual'])
mae_gru = mean_absolute_error(entire_gru_pred['Predictions'], entire_gru_pred['Actual'])
print(f"The Mean Absolute error of LSTM is {mae_lstm}")
print(f"The Mean Absolute error of GRU is {mae_gru}")
# Out:
# The Mean Absolute error of LSTM is 0.09426731183099145
# The Mean Absolute error of GRU is 0.09012534517551896

# %% [markdown]
# ## The model with lowest MSE and MAE is the model that is best fit for Average Wind Speed Prediction based on significant features.
